# %%
#sklearn.datasets for the package that creates the data
from sklearn.datasets import make_regression
#matplotlib to print out and see what the data looks like
import matplotlib.pyplot as plt

# %%
#This represents a very basic, straight line output of the regression output
X,y = make_regression(n_samples=100, n_features=1, noise=0)
plt.scatter(X,y);

# %%
#This shows what happens when when you add a little bit of noise to the data
X,y = make_regression(n_samples=100, n_features=1, noise=5)
plt.scatter(X,y);

# %%
#This has the same amount of noise but has 2 features
X,y = make_regression(n_samples=100, n_features=2, noise=.5)
x1 = [i[0] for i in X]
x2 = [i[1] for i in X]
plt.scatter(x1,y);
plt.scatter(x2,y);

# %%
import models as md
md.run_rfc(X,y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-b8ac8daf6dda> in <module>
#       1 import models as md
# ----> 2 md.run_rfc(X,y)
#
# E:\Python Projects\project repos\Synthetic_Data_Creation\models.py in run_rfc(X, y)
#      38 def run_rfc(X,y):
#      39     X_train, X_test, y_train, y_test = get_split(X,y)
# ---> 40     y_pred = rfc(X_train,y_train,X_test)
#      41     get_results(y_test, y_pred)
#      42     cm, score = get_results(y_test, y_pred)
#
# E:\Python Projects\project repos\Synthetic_Data_Creation\models.py in rfc(X_train, y_train, X_test)
#      17     from sklearn.ensemble import RandomForestClassifier
#      18     rfc = RandomForestClassifier(n_estimators=10, criterion = 'entropy', random_state = 0)
# ---> 19     rfc.fit(X_train,y_train)
#      20     y_pred = rfc.predict(X_test)
#      21     return y_pred
#
# ...

# %%
#This is measuring how gaussian the data is. 
X,y = make_regression(n_samples=100, n_features=1, noise=.5)
#plt.scatter(X,y);
plt.hist(X,bins=10);
